# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient
import os

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
endpoint = os.environ["FORM_RECOGNIZER_ENDPOINT"]
key = os.environ["FORM_RECOGNIZER_KEY"]

# %%
model_id = "20231109_v1"
path_to_sample_documents = "./2311.05490_TEST.pdf"

# %%
document_analysis_client = DocumentAnalysisClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)

# %%
with open(path_to_sample_documents, "rb") as f:
    poller = document_analysis_client.begin_analyze_document(
        model_id, document=f
    )
result = poller.result()

# %%
for idx, document in enumerate(result.documents):
    print("--------Analyzing document #{}--------".format(idx + 1))
    print("Document has type {}".format(document.doc_type))
    print("Document has confidence {}".format(document.confidence))
    print("Document was analyzed by model with ID {}".format(result.model_id))
    for name, field in document.fields.items():
        field_value = field.value if field.value else field.content
        print("......found field of type '{}' with value '{}' and with confidence {}".format(field.value_type, field_value, field.confidence))
# Out:
# --------Analyzing document #1--------
# Document has type 20231109_v1
# Document has confidence 0.021
# Document was analyzed by model with ID 20231109_v1
# ......found field of type 'string' with value 'General Policies, Subgoal Structure, and Planning Width' and with confidence 0.412
# ......found field of type 'string' with value 'Blai Bonet BONETBLAI@GMAIL.COM Universitat Pompeu Fabra, Spain Hector Geffner HECTOR.GEFFNER@ML.RWTH-AACHEN.DE RWTH Aachen University, Germany Linköping University, Sweden' and with confidence 0.379
# ......found field of type 'string' with value 'Abstract It has been observed that many classical planning domains with atomic goals can be solved by means of a simple polynomial exploration procedure, called IW, that runs in time exponential in the problem width, which in these cases is bounded and small. Yet, while the notion of width has become part of state-of-the-art planning algorithms such as BFWS, there is no good explanation for why so many benchmark domains have bounded width when atomic goals are considered. In this work, we address this question by relating bounded width with the existence of general optimal policies that in each planning instance are represented by tuples of atoms of bounded size. We also define the notions of (explicit) serializations and serialized width that have a broader scope as many domains have a bounded serialized width but no bounded width. Such problems are solved non-optimally in polynomial time by a suitable variant of the Serialized IW algorithm. Finally, the language of general policies and the semantics of serializations are combined to yield a simple, meaningful, and expressive language for specifying serializations in compact form in the form of sketches, which can be used for encoding domain control knowledge by hand or for learning it from small examples. Sketches express general problem decompositions in terms of subgoals, and sketches of bounded width express problem decompositions that can be solved in polynomial time.1' and with confidence 0.061
# ......found field of type 'string' with value '1. Introduction Width-based search methods exploit the structure of states to enumerate the state space in ways that are different than "blind" search methods such as breadth-first and depth-first (Lipovetzky & Geffner, 2012). This is achieved by associating a non-negative integer to each state generated in the search, a so-called novelty measure, which is defined by the size of the smallest factor in the state that has not been seen in previously generated states. States are deemed more novel and hence preferred in the exploration search when this novelty measure is smaller. Other types of novelty measures have been used in reinforcement learning for dealing with sparse rewards and in genetic algorithms for dealing with local minima (Tang, Houthooft, Foote, Stooke, Chen, Duan, Schulman, DeTurck, & Abbeel, 2017; Pathak, Agrawal, Efros, & Darrell, 2017; Ostrovski, Bellemare, Oord, & Munos, 2017), but the results are mostly empirical. In classical planning, where novelty measures are part of state-of-the-art search algorithms (Lipovetzky & Geffner, 2017b, 2017a), there is a solid 1. This paper is a heavily revised version of Bonet and Geffner (2021). While the key notions of problem width, general policies, and sketches are from that paper, the relations among these notions have been reworked to make them more meaningful and transparent. The paper also contains many new results. A summary of them and a discussion of their meaning can be found in Sect. 7.' and with confidence None
# ......found field of type 'string' with value 'None' and with confidence 0.994
# ......found field of type 'string' with value 'None' and with confidence 0.916

# %%
for page in result.pages:
    print("\nLines found on page {}".format(page.page_number))
    for line in page.lines:
        print("...Line '{}'".format(line.content.encode('utf-8')))
    for word in page.words:
        print(
            "...Word '{}' has a confidence of {}".format(
                word.content.encode('utf-8'), word.confidence
            )
        )
    for selection_mark in page.selection_marks:
        print(
            "...Selection mark is '{}' and has a confidence of {}".format(
                selection_mark.state, selection_mark.confidence
            )
        )
# Out:
# Lines found on page 1
# ...Line 'b'General Policies, Subgoal Structure, and Planning Width''
# ...Line 'b'Blai Bonet''
# ...Line 'b'Universitat Pompeu Fabra, Spain''
# ...Line 'b'Hector Geffner''
# ...Line 'b'RWTH Aachen University, Germany''
# ...Line 'b'Link\xc3\xb6ping University, Sweden''
# ...Line 'b'BONETBLAI@GMAIL.COM''
# ...Line 'b'HECTOR.GEFFNER@ML.RWTH-AACHEN.DE''
# ...Line 'b'Abstract''
# ...Line 'b'It has been observed that many classical planning domains with atomic goals can be''
# ...Line 'b'solved by means of a simple polynomial exploration procedure, called IW, that runs in''
# ...Line 'b'time exponential in the problem width, which in these cases is bounded and small. Yet,''
# ...Line 'b'while the notion of width has become part of state-of-the-art planning algorithms such as''
# ...Line 'b'BFWS, there is no good explanation for why so many benchmark domains have bounded''
# ...Line 'b'width when atomic goals are considered. In this work, we address this question by relating''
# ...Line 'b'bounded width with the existence of general optimal policies that in each planning instance''
# ...Line 'b'are represented by tuples of atoms of bounded size. We also define the notions of (explicit)''
# ...Line 'b'serializations and serialized width that have a broader scope as many domains have a''
# ...Line 'b'bounded serialized width but no bounded width. Such problems are solved non-optimally''
# ...Line 'b'in polynomial time by a suitable variant of the Serialized IW algorithm. Finally, the''
# ...Line 'b'language of general policies and the semantics of serializations are combined to yield a''
# ...Line 'b'simple, meaningful, and expressive language for specifying serializations in compact form''
# ...Line 'b'in the form of sketches, which can be used for encoding domain control knowledge by hand''
# ...Line 'b'or for learning it from small examples. Sketches express general problem decompositions''
# ...Line 'b'in terms of subgoals, and sketches of bounded width express problem decompositions that''
# ...Line 'b'can be solved in polynomial time.1''
# ...Line 'b'arXiv:2311.05490v1 [cs.AI] 9 Nov 2023''
# ...Line 'b'1. Introduction''
# ...Line 'b'Width-based search methods exploit the structure of states to enumerate the state space in''
# ...Line 'b'ways that are different than "blind" search methods such as breadth-first and depth-first''
# ...Line 'b'(Lipovetzky & Geffner, 2012). This is achieved by associating a non-negative integer to''
# ...Line 'b'each state generated in the search, a so-called novelty measure, which is defined by the size''
# ...Line 'b'of the smallest factor in the state that has not been seen in previously generated states.''
# ...Line 'b'States are deemed more novel and hence preferred in the exploration search when this''
# ...Line 'b'novelty measure is smaller. Other types of novelty measures have been used in reinforcement''
# ...Line 'b'learning for dealing with sparse rewards and in genetic algorithms for dealing with local''
# ...Line 'b'minima (Tang, Houthooft, Foote, Stooke, Chen, Duan, Schulman, DeTurck, & Abbeel, 2017;''
# ...Line 'b'Pathak, Agrawal, Efros, & Darrell, 2017; Ostrovski, Bellemare, Oord, & Munos, 2017), but''
# ...Line 'b'the results are mostly empirical. In classical planning, where novelty measures are part''
# ...Line 'b'of state-of-the-art search algorithms (Lipovetzky & Geffner, 2017b, 2017a), there is a solid''
# ...Line 'b'1. This paper is a heavily revised version of Bonet and Geffner (2021). While the key notions of problem''
# ...Line 'b'width, general policies, and sketches are from that paper, the relations among these notions have been''
# ...Line 'b'reworked to make them more meaningful and transparent. The paper also contains many new results.''
# ...Line 'b'A summary of them and a discussion of their meaning can be found in Sect. 7.''
# ...Word 'b'General'' has a confidence of 0.995
# ...Word 'b'Policies,'' has a confidence of 0.966
# ...Word 'b'Subgoal'' has a confidence of 0.994
# ...Word 'b'Structure,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'Planning'' has a confidence of 0.994
# ...Word 'b'Width'' has a confidence of 0.993
# ...Word 'b'Blai'' has a confidence of 0.993
# ...Word 'b'Bonet'' has a confidence of 0.993
# ...Word 'b'Universitat'' has a confidence of 0.98
# ...Word 'b'Pompeu'' has a confidence of 0.991
# ...Word 'b'Fabra,'' has a confidence of 0.993
# ...Word 'b'Spain'' has a confidence of 0.994
# ...Word 'b'Hector'' has a confidence of 0.995
# ...Word 'b'Geffner'' has a confidence of 0.994
# ...Word 'b'RWTH'' has a confidence of 0.993
# ...Word 'b'Aachen'' has a confidence of 0.94
# ...Word 'b'University,'' has a confidence of 0.992
# ...Word 'b'Germany'' has a confidence of 0.994
# ...Word 'b'Link\xc3\xb6ping'' has a confidence of 0.961
# ...Word 'b'University,'' has a confidence of 0.986
# ...Word 'b'Sweden'' has a confidence of 0.993
# ...Word 'b'BONETBLAI@GMAIL.COM'' has a confidence of 0.961
# ...Word 'b'HECTOR.GEFFNER@ML.RWTH-AACHEN.DE'' has a confidence of 0.935
# ...Word 'b'Abstract'' has a confidence of 0.995
# ...Word 'b'It'' has a confidence of 0.996
# ...Word 'b'has'' has a confidence of 0.996
# ...Word 'b'been'' has a confidence of 0.993
# ...Word 'b'observed'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'many'' has a confidence of 0.987
# ...Word 'b'classical'' has a confidence of 0.993
# ...Word 'b'planning'' has a confidence of 0.994
# ...Word 'b'domains'' has a confidence of 0.994
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'atomic'' has a confidence of 0.994
# ...Word 'b'goals'' has a confidence of 0.994
# ...Word 'b'can'' has a confidence of 0.996
# ...Word 'b'be'' has a confidence of 0.995
# ...Word 'b'solved'' has a confidence of 0.994
# ...Word 'b'by'' has a confidence of 0.996
# ...Word 'b'means'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'simple'' has a confidence of 0.993
# ...Word 'b'polynomial'' has a confidence of 0.99
# ...Word 'b'exploration'' has a confidence of 0.992
# ...Word 'b'procedure,'' has a confidence of 0.99
# ...Word 'b'called'' has a confidence of 0.961
# ...Word 'b'IW,'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'runs'' has a confidence of 0.991
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'time'' has a confidence of 0.992
# ...Word 'b'exponential'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'problem'' has a confidence of 0.995
# ...Word 'b'width,'' has a confidence of 0.993
# ...Word 'b'which'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'these'' has a confidence of 0.995
# ...Word 'b'cases'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'bounded'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'small.'' has a confidence of 0.992
# ...Word 'b'Yet,'' has a confidence of 0.991
# ...Word 'b'while'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'notion'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'width'' has a confidence of 0.995
# ...Word 'b'has'' has a confidence of 0.995
# ...Word 'b'become'' has a confidence of 0.995
# ...Word 'b'part'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'state-of-the-art'' has a confidence of 0.983
# ...Word 'b'planning'' has a confidence of 0.994
# ...Word 'b'algorithms'' has a confidence of 0.992
# ...Word 'b'such'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'BFWS,'' has a confidence of 0.99
# ...Word 'b'there'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.997
# ...Word 'b'no'' has a confidence of 0.996
# ...Word 'b'good'' has a confidence of 0.993
# ...Word 'b'explanation'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'why'' has a confidence of 0.998
# ...Word 'b'so'' has a confidence of 0.996
# ...Word 'b'many'' has a confidence of 0.993
# ...Word 'b'benchmark'' has a confidence of 0.993
# ...Word 'b'domains'' has a confidence of 0.995
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'bounded'' has a confidence of 0.994
# ...Word 'b'width'' has a confidence of 0.994
# ...Word 'b'when'' has a confidence of 0.993
# ...Word 'b'atomic'' has a confidence of 0.995
# ...Word 'b'goals'' has a confidence of 0.995
# ...Word 'b'are'' has a confidence of 0.996
# ...Word 'b'considered.'' has a confidence of 0.981
# ...Word 'b'In'' has a confidence of 0.996
# ...Word 'b'this'' has a confidence of 0.993
# ...Word 'b'work,'' has a confidence of 0.995
# ...Word 'b'we'' has a confidence of 0.995
# ...Word 'b'address'' has a confidence of 0.994
# ...Word 'b'this'' has a confidence of 0.993
# ...Word 'b'question'' has a confidence of 0.994
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'relating'' has a confidence of 0.961
# ...Word 'b'bounded'' has a confidence of 0.995
# ...Word 'b'width'' has a confidence of 0.988
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'existence'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'general'' has a confidence of 0.995
# ...Word 'b'optimal'' has a confidence of 0.995
# ...Word 'b'policies'' has a confidence of 0.994
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.997
# ...Word 'b'each'' has a confidence of 0.993
# ...Word 'b'planning'' has a confidence of 0.993
# ...Word 'b'instance'' has a confidence of 0.994
# ...Word 'b'are'' has a confidence of 0.995
# ...Word 'b'represented'' has a confidence of 0.992
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'tuples'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'atoms'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'bounded'' has a confidence of 0.994
# ...Word 'b'size.'' has a confidence of 0.993
# ...Word 'b'We'' has a confidence of 0.985
# ...Word 'b'also'' has a confidence of 0.992
# ...Word 'b'define'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'notions'' has a confidence of 0.946
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'(explicit)'' has a confidence of 0.973
# ...Word 'b'serializations'' has a confidence of 0.99
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'serialized'' has a confidence of 0.981
# ...Word 'b'width'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.976
# ...Word 'b'broader'' has a confidence of 0.994
# ...Word 'b'scope'' has a confidence of 0.995
# ...Word 'b'as'' has a confidence of 0.951
# ...Word 'b'many'' has a confidence of 0.993
# ...Word 'b'domains'' has a confidence of 0.994
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'bounded'' has a confidence of 0.995
# ...Word 'b'serialized'' has a confidence of 0.993
# ...Word 'b'width'' has a confidence of 0.984
# ...Word 'b'but'' has a confidence of 0.994
# ...Word 'b'no'' has a confidence of 0.992
# ...Word 'b'bounded'' has a confidence of 0.995
# ...Word 'b'width.'' has a confidence of 0.993
# ...Word 'b'Such'' has a confidence of 0.993
# ...Word 'b'problems'' has a confidence of 0.992
# ...Word 'b'are'' has a confidence of 0.996
# ...Word 'b'solved'' has a confidence of 0.992
# ...Word 'b'non-optimally'' has a confidence of 0.972
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'polynomial'' has a confidence of 0.993
# ...Word 'b'time'' has a confidence of 0.965
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'suitable'' has a confidence of 0.993
# ...Word 'b'variant'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'Serialized'' has a confidence of 0.993
# ...Word 'b'IW'' has a confidence of 0.995
# ...Word 'b'algorithm.'' has a confidence of 0.991
# ...Word 'b'Finally,'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.985
# ...Word 'b'language'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.993
# ...Word 'b'policies'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'semantics'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'serializations'' has a confidence of 0.97
# ...Word 'b'are'' has a confidence of 0.995
# ...Word 'b'combined'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'yield'' has a confidence of 0.992
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'simple,'' has a confidence of 0.994
# ...Word 'b'meaningful,'' has a confidence of 0.983
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'expressive'' has a confidence of 0.993
# ...Word 'b'language'' has a confidence of 0.992
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'specifying'' has a confidence of 0.985
# ...Word 'b'serializations'' has a confidence of 0.983
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'compact'' has a confidence of 0.994
# ...Word 'b'form'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.998
# ...Word 'b'form'' has a confidence of 0.988
# ...Word 'b'of'' has a confidence of 0.986
# ...Word 'b'sketches,'' has a confidence of 0.993
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'can'' has a confidence of 0.995
# ...Word 'b'be'' has a confidence of 0.996
# ...Word 'b'used'' has a confidence of 0.991
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'encoding'' has a confidence of 0.994
# ...Word 'b'domain'' has a confidence of 0.995
# ...Word 'b'control'' has a confidence of 0.995
# ...Word 'b'knowledge'' has a confidence of 0.994
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'hand'' has a confidence of 0.993
# ...Word 'b'or'' has a confidence of 0.995
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'learning'' has a confidence of 0.994
# ...Word 'b'it'' has a confidence of 0.995
# ...Word 'b'from'' has a confidence of 0.993
# ...Word 'b'small'' has a confidence of 0.994
# ...Word 'b'examples.'' has a confidence of 0.95
# ...Word 'b'Sketches'' has a confidence of 0.993
# ...Word 'b'express'' has a confidence of 0.993
# ...Word 'b'general'' has a confidence of 0.994
# ...Word 'b'problem'' has a confidence of 0.993
# ...Word 'b'decompositions'' has a confidence of 0.972
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'terms'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'subgoals,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'sketches'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'bounded'' has a confidence of 0.994
# ...Word 'b'width'' has a confidence of 0.994
# ...Word 'b'express'' has a confidence of 0.994
# ...Word 'b'problem'' has a confidence of 0.99
# ...Word 'b'decompositions'' has a confidence of 0.968
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'can'' has a confidence of 0.996
# ...Word 'b'be'' has a confidence of 0.992
# ...Word 'b'solved'' has a confidence of 0.995
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'polynomial'' has a confidence of 0.992
# ...Word 'b'time.1'' has a confidence of 0.885
# ...Word 'b'arXiv:2311.05490v1'' has a confidence of 0.948
# ...Word 'b'[cs.AI]'' has a confidence of 0.961
# ...Word 'b'9'' has a confidence of 0.995
# ...Word 'b'Nov'' has a confidence of 0.995
# ...Word 'b'2023'' has a confidence of 0.993
# ...Word 'b'1.'' has a confidence of 0.995
# ...Word 'b'Introduction'' has a confidence of 0.993
# ...Word 'b'Width-based'' has a confidence of 0.993
# ...Word 'b'search'' has a confidence of 0.995
# ...Word 'b'methods'' has a confidence of 0.995
# ...Word 'b'exploit'' has a confidence of 0.992
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'structure'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'states'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'enumerate'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'state'' has a confidence of 0.995
# ...Word 'b'space'' has a confidence of 0.973
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'ways'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'are'' has a confidence of 0.996
# ...Word 'b'different'' has a confidence of 0.994
# ...Word 'b'than'' has a confidence of 0.982
# ...Word 'b'"blind"'' has a confidence of 0.942
# ...Word 'b'search'' has a confidence of 0.995
# ...Word 'b'methods'' has a confidence of 0.995
# ...Word 'b'such'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.997
# ...Word 'b'breadth-first'' has a confidence of 0.984
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'depth-first'' has a confidence of 0.99
# ...Word 'b'(Lipovetzky'' has a confidence of 0.993
# ...Word 'b'&'' has a confidence of 0.995
# ...Word 'b'Geffner,'' has a confidence of 0.993
# ...Word 'b'2012).'' has a confidence of 0.995
# ...Word 'b'This'' has a confidence of 0.992
# ...Word 'b'is'' has a confidence of 0.997
# ...Word 'b'achieved'' has a confidence of 0.995
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'associating'' has a confidence of 0.992
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'non-negative'' has a confidence of 0.992
# ...Word 'b'integer'' has a confidence of 0.923
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'each'' has a confidence of 0.993
# ...Word 'b'state'' has a confidence of 0.995
# ...Word 'b'generated'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'search,'' has a confidence of 0.994
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'so-called'' has a confidence of 0.993
# ...Word 'b'novelty'' has a confidence of 0.994
# ...Word 'b'measure,'' has a confidence of 0.993
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.961
# ...Word 'b'defined'' has a confidence of 0.995
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'size'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'smallest'' has a confidence of 0.993
# ...Word 'b'factor'' has a confidence of 0.995
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'state'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'has'' has a confidence of 0.995
# ...Word 'b'not'' has a confidence of 0.995
# ...Word 'b'been'' has a confidence of 0.993
# ...Word 'b'seen'' has a confidence of 0.992
# ...Word 'b'in'' has a confidence of 0.98
# ...Word 'b'previously'' has a confidence of 0.991
# ...Word 'b'generated'' has a confidence of 0.993
# ...Word 'b'states.'' has a confidence of 0.993
# ...Word 'b'States'' has a confidence of 0.995
# ...Word 'b'are'' has a confidence of 0.995
# ...Word 'b'deemed'' has a confidence of 0.995
# ...Word 'b'more'' has a confidence of 0.993
# ...Word 'b'novel'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'hence'' has a confidence of 0.995
# ...Word 'b'preferred'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.939
# ...Word 'b'exploration'' has a confidence of 0.993
# ...Word 'b'search'' has a confidence of 0.995
# ...Word 'b'when'' has a confidence of 0.993
# ...Word 'b'this'' has a confidence of 0.993
# ...Word 'b'novelty'' has a confidence of 0.993
# ...Word 'b'measure'' has a confidence of 0.994
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'smaller.'' has a confidence of 0.961
# ...Word 'b'Other'' has a confidence of 0.995
# ...Word 'b'types'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.994
# ...Word 'b'novelty'' has a confidence of 0.994
# ...Word 'b'measures'' has a confidence of 0.993
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'been'' has a confidence of 0.993
# ...Word 'b'used'' has a confidence of 0.983
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'reinforcement'' has a confidence of 0.984
# ...Word 'b'learning'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.992
# ...Word 'b'dealing'' has a confidence of 0.995
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'sparse'' has a confidence of 0.995
# ...Word 'b'rewards'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'genetic'' has a confidence of 0.993
# ...Word 'b'algorithms'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.993
# ...Word 'b'dealing'' has a confidence of 0.961
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'local'' has a confidence of 0.978
# ...Word 'b'minima'' has a confidence of 0.987
# ...Word 'b'(Tang,'' has a confidence of 0.993
# ...Word 'b'Houthooft,'' has a confidence of 0.927
# ...Word 'b'Foote,'' has a confidence of 0.991
# ...Word 'b'Stooke,'' has a confidence of 0.993
# ...Word 'b'Chen,'' has a confidence of 0.994
# ...Word 'b'Duan,'' has a confidence of 0.994
# ...Word 'b'Schulman,'' has a confidence of 0.991
# ...Word 'b'DeTurck,'' has a confidence of 0.975
# ...Word 'b'&'' has a confidence of 0.995
# ...Word 'b'Abbeel,'' has a confidence of 0.991
# ...Word 'b'2017;'' has a confidence of 0.995
# ...Word 'b'Pathak,'' has a confidence of 0.995
# ...Word 'b'Agrawal,'' has a confidence of 0.994
# ...Word 'b'Efros,'' has a confidence of 0.994
# ...Word 'b'&'' has a confidence of 0.995
# ...Word 'b'Darrell,'' has a confidence of 0.994
# ...Word 'b'2017;'' has a confidence of 0.995
# ...Word 'b'Ostrovski,'' has a confidence of 0.993
# ...Word 'b'Bellemare,'' has a confidence of 0.993
# ...Word 'b'Oord,'' has a confidence of 0.995
# ...Word 'b'&'' has a confidence of 0.948
# ...Word 'b'Munos,'' has a confidence of 0.994
# ...Word 'b'2017),'' has a confidence of 0.993
# ...Word 'b'but'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'results'' has a confidence of 0.984
# ...Word 'b'are'' has a confidence of 0.994
# ...Word 'b'mostly'' has a confidence of 0.995
# ...Word 'b'empirical.'' has a confidence of 0.992
# ...Word 'b'In'' has a confidence of 0.997
# ...Word 'b'classical'' has a confidence of 0.993
# ...Word 'b'planning,'' has a confidence of 0.976
# ...Word 'b'where'' has a confidence of 0.992
# ...Word 'b'novelty'' has a confidence of 0.993
# ...Word 'b'measures'' has a confidence of 0.993
# ...Word 'b'are'' has a confidence of 0.995
# ...Word 'b'part'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'state-of-the-art'' has a confidence of 0.98
# ...Word 'b'search'' has a confidence of 0.994
# ...Word 'b'algorithms'' has a confidence of 0.993
# ...Word 'b'(Lipovetzky'' has a confidence of 0.992
# ...Word 'b'&'' has a confidence of 0.995
# ...Word 'b'Geffner,'' has a confidence of 0.992
# ...Word 'b'2017b,'' has a confidence of 0.99
# ...Word 'b'2017a),'' has a confidence of 0.994
# ...Word 'b'there'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'solid'' has a confidence of 0.993
# ...Word 'b'1.'' has a confidence of 0.995
# ...Word 'b'This'' has a confidence of 0.993
# ...Word 'b'paper'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'heavily'' has a confidence of 0.994
# ...Word 'b'revised'' has a confidence of 0.993
# ...Word 'b'version'' has a confidence of 0.984
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'Bonet'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'Geffner'' has a confidence of 0.991
# ...Word 'b'(2021).'' has a confidence of 0.992
# ...Word 'b'While'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.994
# ...Word 'b'key'' has a confidence of 0.995
# ...Word 'b'notions'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'problem'' has a confidence of 0.994
# ...Word 'b'width,'' has a confidence of 0.994
# ...Word 'b'general'' has a confidence of 0.995
# ...Word 'b'policies,'' has a confidence of 0.985
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'sketches'' has a confidence of 0.994
# ...Word 'b'are'' has a confidence of 0.996
# ...Word 'b'from'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'paper,'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'relations'' has a confidence of 0.994
# ...Word 'b'among'' has a confidence of 0.995
# ...Word 'b'these'' has a confidence of 0.995
# ...Word 'b'notions'' has a confidence of 0.995
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'been'' has a confidence of 0.984
# ...Word 'b'reworked'' has a confidence of 0.994
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'make'' has a confidence of 0.993
# ...Word 'b'them'' has a confidence of 0.993
# ...Word 'b'more'' has a confidence of 0.993
# ...Word 'b'meaningful'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'transparent.'' has a confidence of 0.993
# ...Word 'b'The'' has a confidence of 0.995
# ...Word 'b'paper'' has a confidence of 0.961
# ...Word 'b'also'' has a confidence of 0.993
# ...Word 'b'contains'' has a confidence of 0.994
# ...Word 'b'many'' has a confidence of 0.993
# ...Word 'b'new'' has a confidence of 0.996
# ...Word 'b'results.'' has a confidence of 0.995
# ...Word 'b'A'' has a confidence of 0.995
# ...Word 'b'summary'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'them'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'discussion'' has a confidence of 0.987
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'their'' has a confidence of 0.994
# ...Word 'b'meaning'' has a confidence of 0.994
# ...Word 'b'can'' has a confidence of 0.995
# ...Word 'b'be'' has a confidence of 0.995
# ...Word 'b'found'' has a confidence of 0.995
# ...Word 'b'in'' has a confidence of 0.946
# ...Word 'b'Sect.'' has a confidence of 0.994
# ...Word 'b'7.'' has a confidence of 0.994
# ...Selection mark is 'selected' and has a confidence of 0.1
# ...Selection mark is 'unselected' and has a confidence of 0.1
#
# Lines found on page 2
# ...Line 'b'BONET & GEFFNER''
# ...Line 'b'body of theory that relates a specific type of novelty measures with a notion of problem''
# ...Line 'b'width that bounds the complexity of planning problems (Lipovetzky & Geffner, 2012).''
# ...Line 'b'The basic width-based planning algorithms are simple and assume a fixed number of''
# ...Line 'b'Boolean state features F that in classical planning are given by the atoms in the problem.''
# ...Line 'b'The procedure IW(1) is a breadth-first search that starts in the given initial state and prunes''
# ...Line 'b'all the states that do not make a feature from F true for the first time in the search. IW (k)''
# ...Line 'b'is like IW(1) but using conjunctions of up to k features from F instead. Alternatively, IW (k)''
# ...Line 'b'can be regarded as a breadth-first search that prunes states s with novelty measures that''
# ...Line 'b'are greater than k, where the novelty measure of s is the size of the minimum conjunction''
# ...Line 'b'(set) of features that is true in s but false in all the states generated before s.''
# ...Line 'b'For many benchmark domains, it has been shown that IW(k) for a small value of k''
# ...Line 'b'suffices to compute plans, and indeed optimal plans, for any atomic goal (Lipovetzky &''
# ...Line 'b'Geffner, 2012). State-of-the-art planning algorithms like BFWS (Lipovetzky & Geffner,''
# ...Line 'b'2017b, 2017a) make use of this property for serializing conjunctive goals into atomic ones,''
# ...Line 'b'an idea that is also present in algorithms that pre-compute atomic landmarks (Hoffmann,''
# ...Line 'b'Porteous, & Sebastia, 2004) and use them as counting heuristics (Richter & Westphal,''
# ...Line 'b'2010).''
# ...Line 'b'An important open question in the area is why these width-based methods are effective,''
# ...Line 'b'and in particular, why so many domains have a small width when atomic goals are consid-''
# ...Line 'b'ered. Is this a property of the domains? Is it an accident of the domain encodings used? In''
# ...Line 'b'this work, we address these and related questions. For this, we bring the notion of general''
# ...Line 'b'policies; policies that solve multiple instances of a planning domain all at once (Srivastava,''
# ...Line 'b'Immerman, & Zilberstein, 2008; Bonet & Geffner, 2015; Hu & De Giacomo, 2011; Belle &''
# ...Line 'b'Levesque, 2016; Segovia, Jim\xc3\xa9nez, & Jonsson, 2016), while using the formulation of general''
# ...Line 'b'policies expressed in terms of finite sets of rules over a fixed set of Boolean and numerical''
# ...Line 'b'features (Bonet & Geffner, 2018).''
# ...Line 'b'In this paper, a class of instances is shown to have bounded width when there is a general''
# ...Line 'b'optimal policy for the class which can be "followed" in each instance by just considering''
# ...Line 'b'atom tuples of bounded size, without assuming knowledge of the policies or the features''
# ...Line 'b'involved. The existing planning domains that have been shown to have bounded width can''
# ...Line 'b'be all characterized in this way. In addition, the notion of general policies is extended to''
# ...Line 'b'comprise serializations that split problems into subproblems. A serialization has bounded''
# ...Line 'b'width when the resulting subproblems have bounded width and can be solved greedily''
# ...Line 'b'for reaching the problem goal. A general policy turns out to be a serialization of width''
# ...Line 'b'zero; namely, one in which the subproblems can be solved in a single step. Finally, the''
# ...Line 'b'syntax of general policies is combined with the semantics of serializations to yield a simple,''
# ...Line 'b'meaningful, and expressive language for specifying serializations succinctly in the form of''
# ...Line 'b'sketches, which can be used to encode domain control knowledge by hand, or for learning''
# ...Line 'b'it from examples (Drexler, Seipp, & Geffner, 2021, 2022).''
# ...Line 'b'The paper is organized as follows. We review first the notions of planning, width, and''
# ...Line 'b'general policies, and relate width with the size of the tuples of atoms that are needed to''
# ...Line 'b'apply such policies. We then introduce serializations, the more general notion of serialized''
# ...Line 'b'width, the relation between general policies and serialized width, and policy sketches. We''
# ...Line 'b'finally summarize the main contributions, discuss extensions and limitations, related work,''
# ...Line 'b'and conclusions.''
# ...Line 'b'2''
# ...Word 'b'BONET'' has a confidence of 0.995
# ...Word 'b'&'' has a confidence of 0.955
# ...Word 'b'GEFFNER'' has a confidence of 0.994
# ...Word 'b'body'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'theory'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'relates'' has a confidence of 0.987
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'specific'' has a confidence of 0.994
# ...Word 'b'type'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'novelty'' has a confidence of 0.951
# ...Word 'b'measures'' has a confidence of 0.993
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'notion'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'problem'' has a confidence of 0.994
# ...Word 'b'width'' has a confidence of 0.994
# ...Word 'b'that'' has a confidence of 0.991
# ...Word 'b'bounds'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'complexity'' has a confidence of 0.991
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'planning'' has a confidence of 0.992
# ...Word 'b'problems'' has a confidence of 0.993
# ...Word 'b'(Lipovetzky'' has a confidence of 0.99
# ...Word 'b'&'' has a confidence of 0.995
# ...Word 'b'Geffner,'' has a confidence of 0.925
# ...Word 'b'2012).'' has a confidence of 0.993
# ...Word 'b'The'' has a confidence of 0.99
# ...Word 'b'basic'' has a confidence of 0.994
# ...Word 'b'width-based'' has a confidence of 0.983
# ...Word 'b'planning'' has a confidence of 0.95
# ...Word 'b'algorithms'' has a confidence of 0.994
# ...Word 'b'are'' has a confidence of 0.997
# ...Word 'b'simple'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'assume'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'fixed'' has a confidence of 0.994
# ...Word 'b'number'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'Boolean'' has a confidence of 0.994
# ...Word 'b'state'' has a confidence of 0.995
# ...Word 'b'features'' has a confidence of 0.993
# ...Word 'b'F'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'classical'' has a confidence of 0.993
# ...Word 'b'planning'' has a confidence of 0.993
# ...Word 'b'are'' has a confidence of 0.996
# ...Word 'b'given'' has a confidence of 0.995
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'atoms'' has a confidence of 0.995
# ...Word 'b'in'' has a confidence of 0.989
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'problem.'' has a confidence of 0.947
# ...Word 'b'The'' has a confidence of 0.994
# ...Word 'b'procedure'' has a confidence of 0.982
# ...Word 'b'IW(1)'' has a confidence of 0.961
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'breadth-first'' has a confidence of 0.99
# ...Word 'b'search'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'starts'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'given'' has a confidence of 0.994
# ...Word 'b'initial'' has a confidence of 0.993
# ...Word 'b'state'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'prunes'' has a confidence of 0.994
# ...Word 'b'all'' has a confidence of 0.982
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'states'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'do'' has a confidence of 0.995
# ...Word 'b'not'' has a confidence of 0.995
# ...Word 'b'make'' has a confidence of 0.987
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'feature'' has a confidence of 0.993
# ...Word 'b'from'' has a confidence of 0.993
# ...Word 'b'F'' has a confidence of 0.982
# ...Word 'b'true'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'first'' has a confidence of 0.995
# ...Word 'b'time'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'search.'' has a confidence of 0.993
# ...Word 'b'IW'' has a confidence of 0.995
# ...Word 'b'(k)'' has a confidence of 0.941
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'like'' has a confidence of 0.992
# ...Word 'b'IW(1)'' has a confidence of 0.961
# ...Word 'b'but'' has a confidence of 0.995
# ...Word 'b'using'' has a confidence of 0.993
# ...Word 'b'conjunctions'' has a confidence of 0.986
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'up'' has a confidence of 0.996
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'k'' has a confidence of 0.993
# ...Word 'b'features'' has a confidence of 0.991
# ...Word 'b'from'' has a confidence of 0.993
# ...Word 'b'F'' has a confidence of 0.993
# ...Word 'b'instead.'' has a confidence of 0.967
# ...Word 'b'Alternatively,'' has a confidence of 0.985
# ...Word 'b'IW'' has a confidence of 0.993
# ...Word 'b'(k)'' has a confidence of 0.949
# ...Word 'b'can'' has a confidence of 0.995
# ...Word 'b'be'' has a confidence of 0.996
# ...Word 'b'regarded'' has a confidence of 0.994
# ...Word 'b'as'' has a confidence of 0.996
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'breadth-first'' has a confidence of 0.984
# ...Word 'b'search'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'prunes'' has a confidence of 0.994
# ...Word 'b'states'' has a confidence of 0.994
# ...Word 'b's'' has a confidence of 0.861
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'novelty'' has a confidence of 0.994
# ...Word 'b'measures'' has a confidence of 0.991
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'are'' has a confidence of 0.995
# ...Word 'b'greater'' has a confidence of 0.994
# ...Word 'b'than'' has a confidence of 0.993
# ...Word 'b'k,'' has a confidence of 0.993
# ...Word 'b'where'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'novelty'' has a confidence of 0.993
# ...Word 'b'measure'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b's'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'size'' has a confidence of 0.991
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'minimum'' has a confidence of 0.994
# ...Word 'b'conjunction'' has a confidence of 0.992
# ...Word 'b'(set)'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'features'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'true'' has a confidence of 0.983
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b's'' has a confidence of 0.995
# ...Word 'b'but'' has a confidence of 0.995
# ...Word 'b'false'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'all'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.993
# ...Word 'b'states'' has a confidence of 0.974
# ...Word 'b'generated'' has a confidence of 0.992
# ...Word 'b'before'' has a confidence of 0.993
# ...Word 'b's.'' has a confidence of 0.995
# ...Word 'b'For'' has a confidence of 0.997
# ...Word 'b'many'' has a confidence of 0.993
# ...Word 'b'benchmark'' has a confidence of 0.995
# ...Word 'b'domains,'' has a confidence of 0.995
# ...Word 'b'it'' has a confidence of 0.997
# ...Word 'b'has'' has a confidence of 0.996
# ...Word 'b'been'' has a confidence of 0.992
# ...Word 'b'shown'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'IW(k)'' has a confidence of 0.986
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'small'' has a confidence of 0.995
# ...Word 'b'value'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'k'' has a confidence of 0.995
# ...Word 'b'suffices'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.998
# ...Word 'b'compute'' has a confidence of 0.989
# ...Word 'b'plans,'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.993
# ...Word 'b'indeed'' has a confidence of 0.994
# ...Word 'b'optimal'' has a confidence of 0.993
# ...Word 'b'plans,'' has a confidence of 0.994
# ...Word 'b'for'' has a confidence of 0.989
# ...Word 'b'any'' has a confidence of 0.996
# ...Word 'b'atomic'' has a confidence of 0.993
# ...Word 'b'goal'' has a confidence of 0.989
# ...Word 'b'(Lipovetzky'' has a confidence of 0.992
# ...Word 'b'&'' has a confidence of 0.995
# ...Word 'b'Geffner,'' has a confidence of 0.993
# ...Word 'b'2012).'' has a confidence of 0.995
# ...Word 'b'State-of-the-art'' has a confidence of 0.99
# ...Word 'b'planning'' has a confidence of 0.993
# ...Word 'b'algorithms'' has a confidence of 0.995
# ...Word 'b'like'' has a confidence of 0.993
# ...Word 'b'BFWS'' has a confidence of 0.993
# ...Word 'b'(Lipovetzky'' has a confidence of 0.991
# ...Word 'b'&'' has a confidence of 0.948
# ...Word 'b'Geffner,'' has a confidence of 0.993
# ...Word 'b'2017b,'' has a confidence of 0.991
# ...Word 'b'2017a)'' has a confidence of 0.995
# ...Word 'b'make'' has a confidence of 0.99
# ...Word 'b'use'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'this'' has a confidence of 0.982
# ...Word 'b'property'' has a confidence of 0.988
# ...Word 'b'for'' has a confidence of 0.99
# ...Word 'b'serializing'' has a confidence of 0.989
# ...Word 'b'conjunctive'' has a confidence of 0.985
# ...Word 'b'goals'' has a confidence of 0.995
# ...Word 'b'into'' has a confidence of 0.993
# ...Word 'b'atomic'' has a confidence of 0.994
# ...Word 'b'ones,'' has a confidence of 0.993
# ...Word 'b'an'' has a confidence of 0.996
# ...Word 'b'idea'' has a confidence of 0.983
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'also'' has a confidence of 0.993
# ...Word 'b'present'' has a confidence of 0.988
# ...Word 'b'in'' has a confidence of 0.997
# ...Word 'b'algorithms'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.988
# ...Word 'b'pre-compute'' has a confidence of 0.993
# ...Word 'b'atomic'' has a confidence of 0.994
# ...Word 'b'landmarks'' has a confidence of 0.994
# ...Word 'b'(Hoffmann,'' has a confidence of 0.993
# ...Word 'b'Porteous,'' has a confidence of 0.972
# ...Word 'b'&'' has a confidence of 0.993
# ...Word 'b'Sebastia,'' has a confidence of 0.984
# ...Word 'b'2004)'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'use'' has a confidence of 0.995
# ...Word 'b'them'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'counting'' has a confidence of 0.993
# ...Word 'b'heuristics'' has a confidence of 0.99
# ...Word 'b'(Richter'' has a confidence of 0.993
# ...Word 'b'&'' has a confidence of 0.948
# ...Word 'b'Westphal,'' has a confidence of 0.993
# ...Word 'b'2010).'' has a confidence of 0.993
# ...Word 'b'An'' has a confidence of 0.995
# ...Word 'b'important'' has a confidence of 0.994
# ...Word 'b'open'' has a confidence of 0.993
# ...Word 'b'question'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'area'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'why'' has a confidence of 0.997
# ...Word 'b'these'' has a confidence of 0.993
# ...Word 'b'width-based'' has a confidence of 0.992
# ...Word 'b'methods'' has a confidence of 0.993
# ...Word 'b'are'' has a confidence of 0.995
# ...Word 'b'effective,'' has a confidence of 0.972
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'in'' has a confidence of 0.961
# ...Word 'b'particular,'' has a confidence of 0.992
# ...Word 'b'why'' has a confidence of 0.997
# ...Word 'b'so'' has a confidence of 0.995
# ...Word 'b'many'' has a confidence of 0.993
# ...Word 'b'domains'' has a confidence of 0.994
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'small'' has a confidence of 0.995
# ...Word 'b'width'' has a confidence of 0.993
# ...Word 'b'when'' has a confidence of 0.993
# ...Word 'b'atomic'' has a confidence of 0.995
# ...Word 'b'goals'' has a confidence of 0.995
# ...Word 'b'are'' has a confidence of 0.997
# ...Word 'b'consid-'' has a confidence of 0.993
# ...Word 'b'ered.'' has a confidence of 0.994
# ...Word 'b'Is'' has a confidence of 0.995
# ...Word 'b'this'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'property'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'domains?'' has a confidence of 0.961
# ...Word 'b'Is'' has a confidence of 0.995
# ...Word 'b'it'' has a confidence of 0.995
# ...Word 'b'an'' has a confidence of 0.997
# ...Word 'b'accident'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'domain'' has a confidence of 0.995
# ...Word 'b'encodings'' has a confidence of 0.938
# ...Word 'b'used?'' has a confidence of 0.964
# ...Word 'b'In'' has a confidence of 0.995
# ...Word 'b'this'' has a confidence of 0.993
# ...Word 'b'work,'' has a confidence of 0.995
# ...Word 'b'we'' has a confidence of 0.997
# ...Word 'b'address'' has a confidence of 0.993
# ...Word 'b'these'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'related'' has a confidence of 0.994
# ...Word 'b'questions.'' has a confidence of 0.977
# ...Word 'b'For'' has a confidence of 0.997
# ...Word 'b'this,'' has a confidence of 0.995
# ...Word 'b'we'' has a confidence of 0.995
# ...Word 'b'bring'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'notion'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.992
# ...Word 'b'policies;'' has a confidence of 0.986
# ...Word 'b'policies'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'solve'' has a confidence of 0.976
# ...Word 'b'multiple'' has a confidence of 0.993
# ...Word 'b'instances'' has a confidence of 0.989
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'planning'' has a confidence of 0.993
# ...Word 'b'domain'' has a confidence of 0.995
# ...Word 'b'all'' has a confidence of 0.995
# ...Word 'b'at'' has a confidence of 0.995
# ...Word 'b'once'' has a confidence of 0.993
# ...Word 'b'(Srivastava,'' has a confidence of 0.976
# ...Word 'b'Immerman,'' has a confidence of 0.993
# ...Word 'b'&'' has a confidence of 0.976
# ...Word 'b'Zilberstein,'' has a confidence of 0.99
# ...Word 'b'2008;'' has a confidence of 0.992
# ...Word 'b'Bonet'' has a confidence of 0.995
# ...Word 'b'&'' has a confidence of 0.948
# ...Word 'b'Geffner,'' has a confidence of 0.993
# ...Word 'b'2015;'' has a confidence of 0.995
# ...Word 'b'Hu'' has a confidence of 0.996
# ...Word 'b'&'' has a confidence of 0.951
# ...Word 'b'De'' has a confidence of 0.995
# ...Word 'b'Giacomo,'' has a confidence of 0.993
# ...Word 'b'2011;'' has a confidence of 0.992
# ...Word 'b'Belle'' has a confidence of 0.995
# ...Word 'b'&'' has a confidence of 0.949
# ...Word 'b'Levesque,'' has a confidence of 0.981
# ...Word 'b'2016;'' has a confidence of 0.994
# ...Word 'b'Segovia,'' has a confidence of 0.991
# ...Word 'b'Jim\xc3\xa9nez,'' has a confidence of 0.928
# ...Word 'b'&'' has a confidence of 0.991
# ...Word 'b'Jonsson,'' has a confidence of 0.974
# ...Word 'b'2016),'' has a confidence of 0.993
# ...Word 'b'while'' has a confidence of 0.974
# ...Word 'b'using'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'formulation'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.994
# ...Word 'b'policies'' has a confidence of 0.993
# ...Word 'b'expressed'' has a confidence of 0.988
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'terms'' has a confidence of 0.984
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'finite'' has a confidence of 0.993
# ...Word 'b'sets'' has a confidence of 0.991
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'rules'' has a confidence of 0.994
# ...Word 'b'over'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.973
# ...Word 'b'fixed'' has a confidence of 0.993
# ...Word 'b'set'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'Boolean'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'numerical'' has a confidence of 0.993
# ...Word 'b'features'' has a confidence of 0.993
# ...Word 'b'(Bonet'' has a confidence of 0.994
# ...Word 'b'&'' has a confidence of 0.889
# ...Word 'b'Geffner,'' has a confidence of 0.993
# ...Word 'b'2018).'' has a confidence of 0.992
# ...Word 'b'In'' has a confidence of 0.996
# ...Word 'b'this'' has a confidence of 0.993
# ...Word 'b'paper,'' has a confidence of 0.971
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'class'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'instances'' has a confidence of 0.992
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'shown'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'have'' has a confidence of 0.982
# ...Word 'b'bounded'' has a confidence of 0.992
# ...Word 'b'width'' has a confidence of 0.995
# ...Word 'b'when'' has a confidence of 0.993
# ...Word 'b'there'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.992
# ...Word 'b'optimal'' has a confidence of 0.994
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'class'' has a confidence of 0.995
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'can'' has a confidence of 0.995
# ...Word 'b'be'' has a confidence of 0.995
# ...Word 'b'"followed"'' has a confidence of 0.945
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'each'' has a confidence of 0.993
# ...Word 'b'instance'' has a confidence of 0.993
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'just'' has a confidence of 0.993
# ...Word 'b'considering'' has a confidence of 0.992
# ...Word 'b'atom'' has a confidence of 0.99
# ...Word 'b'tuples'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'bounded'' has a confidence of 0.994
# ...Word 'b'size,'' has a confidence of 0.991
# ...Word 'b'without'' has a confidence of 0.995
# ...Word 'b'assuming'' has a confidence of 0.993
# ...Word 'b'knowledge'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'policies'' has a confidence of 0.993
# ...Word 'b'or'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'features'' has a confidence of 0.993
# ...Word 'b'involved.'' has a confidence of 0.993
# ...Word 'b'The'' has a confidence of 0.998
# ...Word 'b'existing'' has a confidence of 0.994
# ...Word 'b'planning'' has a confidence of 0.993
# ...Word 'b'domains'' has a confidence of 0.995
# ...Word 'b'that'' has a confidence of 0.992
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'been'' has a confidence of 0.993
# ...Word 'b'shown'' has a confidence of 0.994
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'bounded'' has a confidence of 0.995
# ...Word 'b'width'' has a confidence of 0.993
# ...Word 'b'can'' has a confidence of 0.995
# ...Word 'b'be'' has a confidence of 0.996
# ...Word 'b'all'' has a confidence of 0.996
# ...Word 'b'characterized'' has a confidence of 0.976
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'this'' has a confidence of 0.992
# ...Word 'b'way.'' has a confidence of 0.993
# ...Word 'b'In'' has a confidence of 0.928
# ...Word 'b'addition,'' has a confidence of 0.991
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'notion'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.994
# ...Word 'b'policies'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.929
# ...Word 'b'extended'' has a confidence of 0.991
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'comprise'' has a confidence of 0.992
# ...Word 'b'serializations'' has a confidence of 0.99
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'split'' has a confidence of 0.995
# ...Word 'b'problems'' has a confidence of 0.993
# ...Word 'b'into'' has a confidence of 0.987
# ...Word 'b'subproblems.'' has a confidence of 0.981
# ...Word 'b'A'' has a confidence of 0.995
# ...Word 'b'serialization'' has a confidence of 0.982
# ...Word 'b'has'' has a confidence of 0.995
# ...Word 'b'bounded'' has a confidence of 0.993
# ...Word 'b'width'' has a confidence of 0.995
# ...Word 'b'when'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'resulting'' has a confidence of 0.994
# ...Word 'b'subproblems'' has a confidence of 0.991
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'bounded'' has a confidence of 0.995
# ...Word 'b'width'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'can'' has a confidence of 0.995
# ...Word 'b'be'' has a confidence of 0.996
# ...Word 'b'solved'' has a confidence of 0.994
# ...Word 'b'greedily'' has a confidence of 0.981
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'reaching'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'problem'' has a confidence of 0.994
# ...Word 'b'goal.'' has a confidence of 0.945
# ...Word 'b'A'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.974
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'turns'' has a confidence of 0.994
# ...Word 'b'out'' has a confidence of 0.994
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'be'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'serialization'' has a confidence of 0.982
# ...Word 'b'of'' has a confidence of 0.984
# ...Word 'b'width'' has a confidence of 0.994
# ...Word 'b'zero;'' has a confidence of 0.995
# ...Word 'b'namely,'' has a confidence of 0.994
# ...Word 'b'one'' has a confidence of 0.997
# ...Word 'b'in'' has a confidence of 0.997
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'subproblems'' has a confidence of 0.993
# ...Word 'b'can'' has a confidence of 0.997
# ...Word 'b'be'' has a confidence of 0.996
# ...Word 'b'solved'' has a confidence of 0.987
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'single'' has a confidence of 0.994
# ...Word 'b'step.'' has a confidence of 0.993
# ...Word 'b'Finally,'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'syntax'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.995
# ...Word 'b'policies'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'combined'' has a confidence of 0.993
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.981
# ...Word 'b'semantics'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'serializations'' has a confidence of 0.983
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'yield'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'simple,'' has a confidence of 0.993
# ...Word 'b'meaningful,'' has a confidence of 0.978
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'expressive'' has a confidence of 0.993
# ...Word 'b'language'' has a confidence of 0.994
# ...Word 'b'for'' has a confidence of 0.995
# ...Word 'b'specifying'' has a confidence of 0.991
# ...Word 'b'serializations'' has a confidence of 0.964
# ...Word 'b'succinctly'' has a confidence of 0.985
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'form'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'sketches,'' has a confidence of 0.993
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'can'' has a confidence of 0.997
# ...Word 'b'be'' has a confidence of 0.996
# ...Word 'b'used'' has a confidence of 0.992
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'encode'' has a confidence of 0.995
# ...Word 'b'domain'' has a confidence of 0.995
# ...Word 'b'control'' has a confidence of 0.995
# ...Word 'b'knowledge'' has a confidence of 0.993
# ...Word 'b'by'' has a confidence of 0.993
# ...Word 'b'hand,'' has a confidence of 0.994
# ...Word 'b'or'' has a confidence of 0.996
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'learning'' has a confidence of 0.995
# ...Word 'b'it'' has a confidence of 0.995
# ...Word 'b'from'' has a confidence of 0.993
# ...Word 'b'examples'' has a confidence of 0.992
# ...Word 'b'(Drexler,'' has a confidence of 0.985
# ...Word 'b'Seipp,'' has a confidence of 0.99
# ...Word 'b'&'' has a confidence of 0.995
# ...Word 'b'Geffner,'' has a confidence of 0.989
# ...Word 'b'2021,'' has a confidence of 0.994
# ...Word 'b'2022).'' has a confidence of 0.979
# ...Word 'b'The'' has a confidence of 0.995
# ...Word 'b'paper'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'organized'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'follows.'' has a confidence of 0.993
# ...Word 'b'We'' has a confidence of 0.997
# ...Word 'b'review'' has a confidence of 0.995
# ...Word 'b'first'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'notions'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'planning,'' has a confidence of 0.962
# ...Word 'b'width,'' has a confidence of 0.989
# ...Word 'b'and'' has a confidence of 0.994
# ...Word 'b'general'' has a confidence of 0.994
# ...Word 'b'policies,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'relate'' has a confidence of 0.995
# ...Word 'b'width'' has a confidence of 0.995
# ...Word 'b'with'' has a confidence of 0.991
# ...Word 'b'the'' has a confidence of 0.962
# ...Word 'b'size'' has a confidence of 0.99
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'tuples'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'atoms'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'are'' has a confidence of 0.995
# ...Word 'b'needed'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.994
# ...Word 'b'apply'' has a confidence of 0.995
# ...Word 'b'such'' has a confidence of 0.973
# ...Word 'b'policies.'' has a confidence of 0.971
# ...Word 'b'We'' has a confidence of 0.996
# ...Word 'b'then'' has a confidence of 0.993
# ...Word 'b'introduce'' has a confidence of 0.993
# ...Word 'b'serializations,'' has a confidence of 0.948
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'more'' has a confidence of 0.993
# ...Word 'b'general'' has a confidence of 0.995
# ...Word 'b'notion'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'serialized'' has a confidence of 0.993
# ...Word 'b'width,'' has a confidence of 0.992
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'relation'' has a confidence of 0.995
# ...Word 'b'between'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.995
# ...Word 'b'policies'' has a confidence of 0.992
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'serialized'' has a confidence of 0.993
# ...Word 'b'width,'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'sketches.'' has a confidence of 0.994
# ...Word 'b'We'' has a confidence of 0.997
# ...Word 'b'finally'' has a confidence of 0.994
# ...Word 'b'summarize'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'main'' has a confidence of 0.993
# ...Word 'b'contributions,'' has a confidence of 0.983
# ...Word 'b'discuss'' has a confidence of 0.993
# ...Word 'b'extensions'' has a confidence of 0.992
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'limitations,'' has a confidence of 0.967
# ...Word 'b'related'' has a confidence of 0.994
# ...Word 'b'work,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'conclusions.'' has a confidence of 0.977
# ...Word 'b'2'' has a confidence of 0.996

# %%
for i, table in enumerate(result.tables):
    print("\nTable {} can be found on page:".format(i + 1))
    for region in table.bounding_regions:
        print("...{}".format(i + 1, region.page_number))
    for cell in table.cells:
        print(
            "...Cell[{}][{}] has content '{}'".format(
                cell.row_index, cell.column_index, cell.content.encode('utf-8')
            )
        )
print("-----------------------------------")
# Out:
# -----------------------------------
